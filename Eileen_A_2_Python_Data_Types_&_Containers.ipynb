# %% [markdown]
# <a href="https://colab.research.google.com/github/eileenIsKewl/Accessibility-Final-Challenge/blob/main/Eileen_A_2_Python_Data_Types_%26_Containers.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🐍 **Python: Data Types & Containers - TEMPLATE**
#
# First, go to `file > save a copy in drive`. This will make a new copy of this notebook. Next, open your new notebook and go to `edit > clear all outputs`. This will make sure that when you run your code, the output is not already shown.
# <br><br>
# 💡 Debugging Tip: If the code is correct and still not running, try refreshing Colab or go to `edit > clear all outputs`, then run again.

# %% [markdown]
# ## 👩‍💻 Using Google Colab

# %% [markdown]
# # Test
# ### test
# **bold**
# 1. first
# 2. next
# * asdasd
# > hdjshdjsh
# `ashdajkdhk`
# [dsajdaskjdadh](example.com)

# %%
print("Hello World!")
# Out:
# Hello World!

# %% [markdown]
# ### **🦎 Try-It | Common Markdown Elements**
#
# Now that you've seen some of the basic Markdown elements in action, you can try it for yourself! [Check out](https://www.markdownguide.org/cheat-sheet/) this resource before completing the steps below.
#
# 1. Create an ordered list of your favorite foods.
# 2. Write an unordered list of your friends' names.
# 3. Insert a link to a coding resource you like.
# 4. Create another Markdown element from the resource provided!

# %% [markdown]
# ## 🔢 Data Types

# %% [markdown]
# ### **🐣 Try-It | Strings**
# Create a new code cell. Inside the cell, type `print("your first name")`. Instead of the words "your first name", type your actual name! You do need to include the quotes.
#
# Type `print("the last thing you ate")`.
#
# Type `print("your full name")`.
#
# Type anything you want inside of the `( )` after `print`. Try to use some characters from your keyboard that are not numbers or letters. Make sure your text is enclosed in quotes.

# %%
print("Eileen")
print("Kebab2831293719371uwqiequo".upper())
# Out:
# Eileen
# KEBAB2831293719371UWQIEQUO

# %% [markdown]
# ### **🐛 Try-It | Strings and Variables**
#
# Complete the following in a new code cell. After you type the code, make sure to run the cell!
#
# Declare a variable for each prompt below. Then, print it out.
#
# - A variable called `favorite_food` that holds your favorite food
# - A variable called `pet` that holds the name of a pet
# - A variable called `school` that holds the name of your high school
# - A variable called `goal` that holds one of your goals. Remember, you can include spaces (and even special characters) in a string!

# %%
favorite_food = "ice cream"
print(f"My favorite food is {favorite_food}")
# Out:
# My favorite food is ice cream

# %% [markdown]
# ### **🦋 Try-It | String Methods**
# Run the code snippet below and observe the output. Be prepared to share your responses to the following questions.
#
# *   What does `lower()` seem to do?
# *   How does `strip()` change the text?
# *   What happens when you use `replace()`?
# *   How do these methods work together in `cleaned_text`?

# %%
text1 = "HeLLo, WoRLd!"
print(text1.lower())

text2 = "   Python is fun!   "
print(text2.strip())

text3 = "Coding is soooo cool!"
print(text3.replace("soooo", "so"))

text4 = "   WELCOME to Python!!!   "
cleaned_text = text4.strip().lower().replace("!!!", "")
print(cleaned_text)
# Out:
# hello, world!
# Python is fun!
# Coding is so cool!
# welcome to python

# %% [markdown]
# ### **🪲 Try-It | Clean Up Messy Text**
# Use Python string methods to clean up this messy text.
#
# 1.   Remove extra spaces from the beginning and the end of the string
# 2.   Convert all letters to lowercase
# 3.   Remove all punctuation

# %%
messy_text = "   HeLlO, wOrLd!   ".strip().replace("O", "o").replace("L", "l")
print(messy_text)
# Out:
# Hello, world!

# %% [markdown]
# ### **🐌 Try-It | Numbers**
#
# Run the code below to see the answers to the following calculations:

# %%
# Addition, subtraction
print(5 + 5)
print(5 - 5)

# Multiplication, division, and exponentiation
print(3 * 5)
print(10 / 2)
print(4 ** 2)
# Out:
# 10
# 0
# 15
# 5.0
# 16

# %% [markdown]
# ### **🐢 Try-It | Numbers & Calculations**
#
# Complete the following in a new code cell. After you type the code, make sure to run the cell!
#
# - Create an expression that equals 100
# - Write an expression with two or more operators
# - Create an expression using a variable
#
# 🌶️ **Spicy Challenge:** How would Python evaluate the following expression?
# ```
# magic_number = (20 - 3 * 5) ** 2 - (50 / 2) + (15 % 4)
# ```

# %%
# result is 3.0
magic_number = (20 - 3 * 5) ** 2 - (50 / 2) + (15 % 4)
print(magic_number)

print(4+3+2323232323232323/234234234//34343)
# Out:
# 3.0

# %% [markdown]
# ## 🎁 Containers

# %% [markdown]
# ### **🐞 Try-It | Lists**
#
# 1. Create a new, empty list called `scholars`.
# 2. Append your name to the list as a string.
# 3. Append the following names as strings (in order):
#     - Karlie
#     - Serena
#     - Miley
#     - Ariana
#     - Selena
# 4. Sort the list, then print the list to view the newly sorted list. [Hint](https://www.programiz.com/python-programming/methods/list)
# 5. Reverse the list, then print to view the reversed list. [Hint](https://www.programiz.com/python-programming/methods/list)
# 6. Add an additional person to the list, then print the updated list.

# %%
scholars = []
scholars.append("Eileen")
scholars.extend(["Karlie", "Serena", "Miley", "Ariana", "Selena"])
scholars.sort()
scholars.reverse()
scholars.append("Madeline")

# %% [markdown]
# ### **🦚 Try-It | Nested Data Structures**
# Using the `user_profile` dictionary, figure out how to access the following values. Remember to use `print()` to see the output!
#
# 1. The user’s subscription type.
# 2. The total minutes the user has listened to music.
# 3. The first song in the `Throwbacks` playlist.
# 4. The second artist in their `top_artists` list.

# %%
user_profile = {
    "username": "MusicLover23",
    "email": "musiclover23@example.com",
    "subscription": "Premium",
    "playlists": {
        "Chill Vibes": ["Enchanted", "Cool", "Feather"],
        "Hype Mode": ["Shake It Off", "Physical", "Espresso"],
        "Throwbacks": ["Love Story", "New Rules", "Thumbs"]
    },
    "top_artists": ["Taylor Swift", "Dua Lipa", "Sabrina Carpenter"],
    "listening_stats": {
        "minutes_listened": 34567,
        "most_played_song": "Espresso",
        "favorite_genre": "Pop"
    }
}

print(user_profile["subscription"])
print(user_profile["listening_stats"]["minutes_listened"])
print(user_profile["playlists"]["Throwbacks"][0])
print(user_profile["top_artists"][1])
# Out:
# Premium
# 34567
# Love Story
# Dua Lipa

# %% [markdown]
# ### **🐝 Practice | Data Types & Containers**
#
# You’ve now seen and used the foundations of Python. Complete the exercises below for a little more practice.
#
# Create a new code cell block.
#
# 1. Create a dictionary called **me** that contains the following key-value pairs:
#     - "name": where the value is your name as a `string`
#     - "age": where the value is your age as a `integer`
# 2. Print your name from the dictionary.
# 3. Add a new key-value pair to your **me** dictionary, where the key is the `string` "hobbies" and the value is an empty list.
# 4. Append a hobby (or two!) as a string to your hobbies list.

# %% [markdown]
# 🌶️ Spicy Challenge: Use you online sleuthing skills to learn about string interpolation. Print the statement "My name is [YOUR NAME HERE]" by combining a string with your dictionary!

# %%
me = {
    "name": "Eileen",
    "age": 15,
}
print(me["name"])
me["hobbies"] = ["coding", "3D modelling"]
me["hobbies"].extend(["game development", "piano", "art"])
print(me)
print(f"My name is {me["name"]} and my age is {me["age"]}.")
# Out:
# Eileen
# {'name': 'Eileen', 'age': 15, 'hobbies': ['coding', '3D modelling', 'game development', 'piano', 'art']}
# My name is Eileen and my age is 15.
